# %% [markdown]
# **Churn Modelling Prediction**

# %% [markdown]
# Churn prediction is the process of analyzing customer data to determine the likelihood that a customer will stop using a company's product or service. This can apply to various industries, including telecommunications, banking, subscription services, and more.
#
# This dataset which is accessed from Kaggle has 10000 records to investigate and predict which of the customers are more likely to leave the bank soon.
#
# We have implemented Arficial Neural Networks(ANN) as well as MultiLayer Perceptron(MLP) and analysed the accuracies.

# %%
#Loading the required libraries
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense,Flatten
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from warnings import filterwarnings
filterwarnings('ignore')
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
#Loading the data and displaying the content
df=pd.read_csv('Churn_Modelling.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  ... HasCrCard IsActiveMember  EstimatedSalary  Exited
# 0          1    15634602  Hargrave          619  ...         1              1        101348.88       1
# 1          2    15647311      Hill          608  ...         0              1        112542.58       0
# 2          3    15619304      Onio          502  ...         1              0        113931.57       1
# 3          4    15701354      Boni          699  ...         0              0         93826.63       0
# 4          5    15737888  Mitchell          850  ...         1              1         79084.10       0
#
# [5 rows x 14 columns]

# %%
#Analysing the attributes
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
# Plotting the Churn distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='Exited', data=df)
plt.title('Churn Distribution')
plt.xlabel('Exited (0 = Not Churned, 1 = Churned)')
plt.ylabel('Count')
plt.show()

# %%
#Selecting the categorical attributes alone to get encoded
categorical_cols = df.select_dtypes(include=['object'])
categorical_cols
# Out:
#         Surname Geography  Gender
# 0      Hargrave    France  Female
# 1          Hill     Spain  Female
# 2          Onio    France  Female
# 3          Boni    France  Female
# 4      Mitchell     Spain  Female
# ...         ...       ...     ...
# 9995   Obijiaku    France    Male
# 9996  Johnstone    France    Male
# 9997        Liu    France  Female
# 9998  Sabbatini   Germany    Male
# 9999     Walker    France  Female
#
# [10000 rows x 3 columns]

# %%
#Using LabelEncoder to encode
label_encoder = LabelEncoder()

# %%
for col in categorical_cols:
    df[col] = label_encoder.fit_transform(df[col])

# %%
#Displaying data after encoding
df.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore  ...  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1    15634602     1115          619  ...          1               1        101348.88       1
# 1          2    15647311     1177          608  ...          0               1        112542.58       0
# 2          3    15619304     2040          502  ...          1               0        113931.57       1
# 3          4    15701354      289          699  ...          0               0         93826.63       0
# 4          5    15737888     1822          850  ...          1               1         79084.10       0
#
# [5 rows x 14 columns]

# %%
#Finding the correlation and visualising using heatmap
plt.figure(figsize=(12, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
#Information about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  int64
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  int64
#  5   Gender           10000 non-null  int64
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(12)
# memory usage: 1.1 MB

# %%
#Data description
df.describe()
# Out:
#          RowNumber    CustomerId       Surname  ...  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000  1.000000e+04  10000.000000  ...    10000.000000     10000.000000  10000.000000
# mean    5000.50000  1.569094e+07   1507.774200  ...        0.515100    100090.239881      0.203700
# std     2886.89568  7.193619e+04    846.204311  ...        0.499797     57510.492818      0.402769
# min        1.00000  1.556570e+07      0.000000  ...        0.000000        11.580000      0.000000
# 25%     2500.75000  1.562853e+07    773.750000  ...        0.000000     51002.110000      0.000000
# 50%     5000.50000  1.569074e+07   1542.000000  ...        1.000000    100193.915000      0.000000
# 75%     7500.25000  1.575323e+07   2238.250000  ...        1.000000    149388.247500      0.000000
# max    10000.00000  1.581569e+07   2931.000000  ...        1.000000    199992.480000      1.000000
#
# [8 rows x 14 columns]

# %%
#Checking for null values
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
#Inputs x and y
x = df.drop(columns=['Exited'])
y = df['Exited']

# %%
#Standardization of inputs
scaler = StandardScaler()
x = scaler.fit_transform(x)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
#Splitting train-test data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
#Importing the libraries for ANN
from tensorflow import keras
from tensorflow.keras import layers

# %%
#Input features
x.shape
# Out:
# (10000, 13)

# %%
#Finding classes
num_labels=len(np.unique(y_train))
num_labels
# Out:
# 2

# %%
#Defining ANN model
#Model contains Input layer, hidden layer and output layer
model = keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(x_train.shape[1],)),
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# %%
#Compilation of the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
#Model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_27 (Dense)                     │ (None, 32)                  │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_28 (Dense)                     │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_29 (Dense)                     │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,981 (11.65 KB)
#  Trainable params: 993 (3.88 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,988 (7.77 KB)

# %%
#Execution of the model
history=model.fit(x_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8784 - loss: 0.2974 - val_accuracy: 0.8400 - val_loss: 0.3611
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8772 - loss: 0.3007 - val_accuracy: 0.8431 - val_loss: 0.3635
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8798 - loss: 0.2856 - val_accuracy: 0.8394 - val_loss: 0.3683
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8766 - loss: 0.2970 - val_accuracy: 0.8338 - val_loss: 0.3777
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8923 - loss: 0.2712 - val_accuracy: 0.8350 - val_loss: 0.3744
# Epoch 35/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8926 - loss: 0.2689 - val_accuracy: 0.8350 - val_loss: 0.3779
# Epoch 36/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8871 - loss: 0.2731 - val_accuracy: 0.8356 - val_loss: 0.3768
# Epoch 37/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8813 - loss: 0.2827 - val_accuracy: 0.8369 - val_loss: 0.3749
# Epoch 38/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8871 - loss: 0.2700 - val_accuracy: 0.8394 - val_loss: 0.3786
# Epoch 39/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8903 - loss: 0.2621 - val_accuracy: 0.8363 - val_loss: 0.3785
# Epoch 40/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8816 - loss: 0.2791 - val_accuracy: 0.8406 - val_loss: 0.3823
# Epoch 41/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8903 - loss: 0.2696 - val_accuracy: 0.8331 - val_loss: 0.3795
# Epoch 42/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8887 - loss: 0.2756 - val_accuracy: 0.8394 - val_loss: 0.3843
# Epoch 43/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8903 - loss: 0.2707 - val_accuracy: 0.8344 - val_loss: 0.3815
# Epoch 44/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8881 - loss: 0.2711 - val_accuracy: 0.8344 - val_loss: 0.3807
# Epoch 45/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8915 - loss: 0.2656 - val_accuracy: 0.8306 - val_loss: 0.3838
# Epoch 46/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8940 - loss: 0.2556 - val_accuracy: 0.8325 - val_loss: 0.3846
# Epoch 47/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8868 - loss: 0.2678 - val_accuracy: 0.8375 - val_loss: 0.3832
# Epoch 48/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8859 - loss: 0.2760 - val_accuracy: 0.8325 - val_loss: 0.3845
# Epoch 49/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8926 - loss: 0.2591 - val_accuracy: 0.8313 - val_loss: 0.3860
# Epoch 50/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8931 - loss: 0.2687 - val_accuracy: 0.8300 - val_loss: 0.3862

# %%
#Visualising the model Accuracy
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Model loss Visualisation
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Testing Loss', linestyle='--')
plt.title('Training and Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([[0.03223386],
#        [0.0098585 ],
#        [0.09222329],
#        ...,
#        [0.8031892 ],
#        [0.05905572],
#        [0.6231543 ]], dtype=float32)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report

# %%
#Converting the predictions into integer
y_pred=y_pred.astype(int)

# %%
#Confusion matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[1607    0]
#  [ 390    3]]

# %%
#Precision and Recall
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89      1607
#            1       1.00      0.01      0.02       393
#
#     accuracy                           0.81      2000
#    macro avg       0.90      0.50      0.45      2000
# weighted avg       0.84      0.81      0.72      2000

# %%
#Using MLP Classifier and comparing the accuracy
from sklearn.neural_network import MLPClassifier

# %%
#Defining model using MLPClassifier and finding accuracy
model1=MLPClassifier()
model1.fit(x_train,y_train)
y_pred=model1.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.858

# %% [markdown]
# Result:
#
# As per the results, the model has the highest accuracy for ANN when compared to MLP.
